# %%
import pandas as pd

# %%
data = pd.read_csv('data/hexagon.csv')
data
# Out:
#             x         y  c
# 0    2.402047  3.728695  1
# 1   -0.660032  7.047206  0
# 2    2.202839 -2.394303  2
# 3    3.179183  2.593885  1
# 4    3.173320 -2.152688  2
# ..        ...       ... ..
# 595 -2.186246 -4.059754  4
# 596  4.089715 -2.879358  2
# 597 -3.014489 -2.824257  4
# 598  3.746346  3.001876  1
# 599 -0.434860 -5.911340  3
#
# [600 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='x', y='y', hue='c', palette='viridis', s=100)
plt.title('Wizualizacja punktów')
plt.legend(title='Kolor (c)')
plt.show()

# %%
data2 = pd.read_csv('data/cube.csv')
data2
# Out:
#              x         y         z  c
# 0     0.187781  0.239537  0.382492  0
# 1    -1.308979 -0.143321 -0.966648  0
# 2    -0.987613  0.679918 -0.037552  0
# 3     0.924980  0.607235 -0.146856  0
# 4    -0.098663  0.004329 -0.588876  0
# ...        ...       ...       ... ..
# 1195  2.740583  3.037202  2.723101  7
# 1196  2.303258  4.337946  2.798172  7
# 1197  3.528407  4.575523  1.406155  7
# 1198  2.236023  3.901189  1.529630  7
# 1199  2.735838  4.306381  2.097501  7
#
# [1200 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(
    data2['x'],
    data2['y'],
    data2['z'],
    c=data2['c'],
    cmap='viridis',   # paleta kolorów
    s=50              # wielkość punktu
)

fig.colorbar(scatter, ax=ax, label='Kolor (c)')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Wizualizacja punktów')

plt.show()

# %%
mnist = pd.read_csv('data/mnist.csv')
mnist_X = mnist.drop(columns=['label']).values 
mnist_true_labels = mnist['label'].values

# %%
import numpy as np
import pandas as pd
activity_X = np.loadtxt('data/activity_X_train.txt')
activity_true_labels = np.loadtxt('data/activity_y_train.txt')

# %%
hexagon = pd.read_csv('data/hexagon.csv')
hexagon_X = hexagon[['x', 'y']].values 
hexagon_true_labels = hexagon['c'].values

# %%
activity_X
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# ...        ...       ...       ...       ...       ...       ...       ...
# 7347  0.299665 -0.057193 -0.181233 -0.195387  0.039905  0.077078 -0.282301
# 7348  0.273853 -0.007749 -0.147468 -0.235309  0.004816  0.059280 -0.322552
# 7349  0.273387 -0.017011 -0.045022 -0.218218 -0.103822  0.274533 -0.304515
# 7350  0.289654 -0.018843 -0.158281 -0.219139 -0.111412  0.268893 -0.310487
# 7351  0.351503 -0.012423 -0.203867 -0.269270 -0.087212  0.177404 -0.377404
#
# ...
